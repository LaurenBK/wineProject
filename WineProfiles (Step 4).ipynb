# %%
import networkx as nx
import mpld3
import matplotlib.pyplot as plt
from numpy import random
import pandas as pd
import numpy as np
import sys
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import time
import nltk
import gensim
from gensim.models.doc2vec import Doc2Vec
from scipy.spatial.distance import cosine
import re
import pickle

sns.set_palette('Dark2')
plt.rcParams['figure.figsize'] = (8,6)
# %matplotlib inline

# custom file
import wine_config # wine_config.get_config() is a dict
config = wine_config.get_config()

# %%
path = config['path']

wines = pd.read_csv(
    path +'Google Drive/Data Science/WineData/cleaned_wine_data.csv', 
    encoding='utf-8')

# %%
wines.head()
# Out:
#             @context                                         @id    @type  \
# 0  http://schema.org  https://wine.co.za/wine/wine.aspx?WINEID=2  Product
# 1  http://schema.org  https://wine.co.za/wine/wine.aspx?WINEID=4  Product
# 2  http://schema.org  https://wine.co.za/wine/wine.aspx?WINEID=5  Product
# 3  http://schema.org  https://wine.co.za/wine/wine.aspx?WINEID=6  Product
# 4  http://schema.org  https://wine.co.za/wine/wine.aspx?WINEID=7  Product
#
#     alc            category closure  \
# 0  17.0  Muscat dAlexandrie     NaN
# 1  12.0  Cabernet Sauvignon     NaN
# 2  12.0  Cabernet Sauvignon     NaN
# 3  13.0              Shiraz     NaN
# 4  12.0     Sauvignon Blanc     NaN
#
#                                          description foodnote  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2  Immense in all proportions, this wine defines ...      NaN
# 3  This is an elegant and flavoursome Shiraz with...      NaN
# 4  A well balanced, full tropical flavoured with ...      NaN
#
#                                                image  \
# 0  http://images.wine.co.za/GetWineImage.ashx?Ima...
# 1  http://images.wine.co.za/GetWineImage.ashx?Ima...
# 2  http://images.wine.co.za/GetWineImage.ashx?Ima...
# 3  http://images.wine.co.za/GetWineImage.ashx?Ima...
# 4  http://images.wine.co.za/GetWineImage.ashx?Ima...
#
#                                    name   ...     rs  size sku  style   ta  \
# 0     L Emigre Muscat d Alexandrie 1998   ...    NaN   NaN   2    NaN  NaN
# 1  Genesis Cabernet Sauvignon 1997/1998   ...    1.0   NaN   4    NaN  5.0
# 2          Rustenberg Peter Barlow 1996   ...    1.0   NaN   5   Dry   6.0
# 3              Henri Roselt Shiraz 1999   ...    2.0   NaN   6    NaN  5.0
# 4           Boland Sauvignon Blanc 2000   ...    4.0   NaN   7    NaN  6.0
#
#      type             variety      winemaker     wood    year
# 0     NaN  Muscat dAlexandrie            NaN      NaN  1998.0
# 1    Red   Cabernet Sauvignon    Chris Kelly      NaN  1998.0
# 2    Red   Cabernet Sauvignon   Rod Easthope   wooded  1996.0
# 3    Red               Shiraz   Andr van Dyk      NaN  1999.0
# 4  White      Sauvignon Blanc  Johan Joubert      NaN  2000.0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Assigning profiles

# %% [markdown]
# Using the wine profiles described in https://winefolly.com/tutorial/wine-aroma-wheel-100-flavors/ and updating it with words seen in the wine descriptions, we have a list of wine flavour profiles and words that belong to each profile

# %%
complete_corpus = pickle.load(open('preprocessed_descriptions.pkl',
                 'wb'))

# %%
comlete_corpus[:10]
# Out:
# 0    [immense, in, all, proportions, this, wine, de...
# 1    [this, is, an, elegant, and, flavoursome, shir...
# 2    [a, well, balanced, full, tropical, flavoured,...
# 3    [a, ruby, tipe, port, blended, from, ruby, cab...
# 4    [dry, wine, with, fruity, quava, bouquet, and,...
# Name: description, dtype: object

# %%
profiles = pd.read_csv('flavourProfiles.csv', index_col=0)
profiles
# Out:
#                           Profile  \
# 0                          Flower
# 1                          Citrus
# 2                      Tree Fruit
# 3                  Tropical Fruit
# 4                       Red Fruit
# 5                     Black Fruit
# 6                     Dried Fruit
# 7                       Noble Rot
# 8                           Spice
# 9                       Vegetable
# 10                          Earth
# 11                      Microbial
# 12                      Oak Aging
# 13                  General Aging
# 14                Cork Taint(TCA)
# 15          Sulfides & Mercaptans
# 16                  Brettanomyces
# 17          Madeirized (orCooked)
# 18  Volatile Acidity (AceticAcid)
#
#                                             Varieties
# 0   iris,peony,elderflower,acacia,lilac,jasmine,ho...
# 1   lime,lemon,grapefruit,orange,marmalade,lemons,...
# 2   quince,apple,pear,nectarine,peach,apricot,pers...
# 3   pineapple,mango,guava,passion fruit,lychee,bub...
# 4   cranberry,red plum,pomegranate,sour cherry,str...
# 5   boysenberry,blackcurrant,black cherry,plum,bla...
# 6           raisin,fig,date,fruit cake,figs,fruitcake
# 7                               bees wax,ginger,honey
# 8   white pepper,red pepper,black pepper,cinnamon,...
# 9   grass,tomato leaf,gooseberry,bell pepper,jalap...
# 10  claypot,slate,wet gravel,potting soil,red beet...
# 11      butter,cream,sourdough,lager,truffle,mushroom
# 12  vanilla,coconut,baking spices,cigarbox,smoke,d...
# 13  nutty flavors,tobacco,coffee,cocoa,leather,haz...
# 14                    musty cardboard,wet dog,venison
# 15  cured meat,boiled eggs,burnt rubber,lit match,...
# 16  black cardamon,band-aid,sweaty leather saddle,...
# 17                   toffee,stewed fruit,butterscotch
# 18           vinegar,nail polish remover,acid,vineyar

# %%
profiles['Varieties'] = profiles['Varieties'].apply(lambda x: x.split(','))
profiles.head()
# Out:
#           Profile                                          Varieties
# 0          Flower  [iris, peony, elderflower, acacia, lilac, jasm...
# 1          Citrus  [lime, lemon, grapefruit, orange, marmalade, l...
# 2      Tree Fruit  [quince, apple, pear, nectarine, peach, aprico...
# 3  Tropical Fruit  [pineapple, mango, guava, passion fruit, lyche...
# 4       Red Fruit  [cranberry, red plum, pomegranate, sour cherry...

# %%
import gensim

model = Doc2Vec.load('descriptions_doc2vec')

# Load Google's pre-trained Word2Vec model.
# model = gensim.models.KeyedVectors.load_word2vec_format('./GoogleNews-vectors-negative300.bin', binary=True)

# %%
profile_vectors = []
for p in profiles.Varieties:
    vec = model.infer_vector(p)
    profile_vectors.append(vec)

# %%
def most_likely_profiles(row, profiles, 
                         profile_vectors,
                         model):
    position = row.name
    similarities = [0] * len(profiles)
    for profile in range(len(profiles)):
        profile_vec = profile_vectors[profile]
        tokens = tokenize(row.description)
        text_vec = model.infer_vector(tokens)
        sim = cosine(text_vec, profile_vec)
        similarities[profile] = sim
    similarities = np.array(similarities)
    most_similar = similarities.argsort()[-3:][::-1]
    most_similar_profiles = list(
        profiles.Profile.loc[most_similar])
    row['First'] = most_similar_profiles[0]
    row['Second'] = most_similar_profiles[1]
    row['Third'] = most_similar_profiles[2]
    return row

# %%
top3_profiles = wines[['description']]
top3_profiles['First'] = ''
top3_profiles['Second'] = ''
top3_profiles['Third'] = ''
top3_profiles.apply(lambda x: most_likely_profiles(x,
                                                   profiles,
                                                   profile_vectors,
                                                   model),
                    axis=1)
# Out:
# /Users/lauren/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/lauren/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/lauren/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                                              description  \
# 0      Immense in all proportions, this wine defines ...
# 1      This is an elegant and flavoursome Shiraz with...
# 2      A well balanced, full tropical flavoured with ...
# 3      A Ruby tipe port blended from Ruby Cabernet, f...
# 4        Dry wine with fruity quava bouquet and flavour.
# 5      This wine is supported by a full bouquet of pe...
# 6      This wine shows lemon, melon and citrus flavou...
# 7      A refined, dry white wine, subtly wooded, with...
# 8      A naturally fermented Apple wine with the dept...
# 9      Bright and clear, a light straw colour with a ...
# 10     Dark red, clear and brilliant.Blackberry, with...
# 11     Bright and clear, the colour of straw with ple...
# 12     The wine has a pale straw colour. The nose has...
# 13     The maiden vintage was released to celebrate t...
# 14     A wine with an intense colour packed with conc...
# 15     Bright and clear, with a light straw colour. P...
# 16     Brilliant dark red, clear and brightcolour. Fr...
# 17     A Ferrari Sauvignon Blanc!  This wine exudes t...
# 18     Succulent tropical fruits with hints of green ...
# 19     Ruby red, clear and brilliant. A touch of mulb...
# 20     A beautiful Chardonnay, produced from grapes g...
# 21     The South African Trophy Wine Show 2002 - Bron...
# 22     Fairburn Capital Trophy Wine Awards - Silver M...
# 23     4 Stars in Wine, August 2000 editionBest value...
# 24     The typical herbaceous character of the Sauvig...
# 25     This vivacious, light, but dry sparkling wine,...
# 26     A bright and fresh sparkling wine, with a trop...
# 27     A sweet non-alcoholic sparkling drink with all...
# 28     This is a dry, fresh and appetising wine made ...
# 29     A crisp and light style wine with a fruity bou...
# ...                                                  ...
# 27657  Bursting with aromas of gooseberry and passion...
# 27658  Roasted almond dominates with an elegant but w...
# 27659  Pale, golden colour with flavours of roasted c...
# 27660  Red fruit flavours of cherry and strawberry gi...
# 27661  The wine is lively and fresh with a hint of pa...
# 27662  Colour: Rich brick red.Nose: Full ripe raisins...
# 27663  A medium to full-bodied wine made in a fresh a...
# 27664  This wine was matured in new and fourth fill A...
# 27665  The 2016 is a true gem: exceptionally intense ...
# 27666  This elegant Cabernet Sauvignon with typical v...
# 27667  1 bottle JAN Special Cuvee Red - Colour: Vibra...
# 27668  This silky, fruit driven blend has prominent f...
# 27669  A well-rounded blend of Pinotage and Merlot, p...
# 27670  Fragrant, playful, fresh and fun! A bubbly, fr...
# 27671  A refreshing, well balanced styled wine with a...
# 27672  This is the one! An oak-matured wine with roas...
# 27673  A fountain of flowery aromas alerts first impr...
# 27674  Distinctive aromas of tomato leaf, pencil shav...
# 27675  An elegant yet vibrant wine. Lighter in style ...
# 27676  This eloquent blend rewards with the finest at...
# 27677  Colour: Vibrant with youthful nuances. Nose: N...
# 27678  Inviting aromas of grapefruit, citrus and oran...
# 27679  Instant appeal from the pale copper pink blush...
# 27680  Whiffs of fresh pear, pineapple and rock melon...
# 27681  A rare cultivar with 77 hectares remaining lef...
# 27682  The Cederberg Ros&eacute;, made of single vine...
# 27683  The world&rsquo;s first White Pinotage &ldquo;...
# 27684  A pale golden color with lime green tinges giv...
# 27685  Light Pomegranate in colour, this is what summ...
# 27686  Initially a subdued bouquet opens up to aromas...
#
#                                First                         Second  \
# 0              Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 1              Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 2      Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 3              Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 4              Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 5      Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 6      Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 7      Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 8                          Oak Aging                  General Aging
# 9              Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 10             Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 11             Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 12             Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 13             Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 14     Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 15     Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 16             Sulfides & Mercaptans                      Oak Aging
# 17     Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 18     Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 19             Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 20     Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 21             Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 22             Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 23     Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 24             Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 25             Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 26             Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27             Sulfides & Mercaptans                Cork Taint(TCA)
# 28     Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 29     Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# ...                              ...                            ...
# 27657          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27658  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27659          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27660  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27661  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27662  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27663          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27664          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27665  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27666  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27667          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27668  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27669          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27670  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27671          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27672          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27673          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27674          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27675  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27676  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27677          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27678          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27679          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27680  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27681          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27682  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27683  Volatile Acidity (AceticAcid)          Sulfides & Mercaptans
# 27684          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27685          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
# 27686          Sulfides & Mercaptans  Volatile Acidity (AceticAcid)
#
#                                Third
# 0                          Noble Rot
# 1                          Oak Aging
# 2                          Oak Aging
# 3                          Microbial
# 4                          Oak Aging
# 5                          Vegetable
# 6                        Dried Fruit
# 7                          Oak Aging
# 8                      Brettanomyces
# 9                          Vegetable
# 10                         Noble Rot
# 11                         Oak Aging
# 12                            Flower
# 13                         Microbial
# 14                         Oak Aging
# 15                         Oak Aging
# 16     Volatile Acidity (AceticAcid)
# 17                         Noble Rot
# 18                         Oak Aging
# 19                         Oak Aging
# 20                         Oak Aging
# 21                         Oak Aging
# 22                         Oak Aging
# 23                         Microbial
# 24                         Oak Aging
# 25                         Oak Aging
# 26                         Oak Aging
# 27     Volatile Acidity (AceticAcid)
# 28                         Oak Aging
# 29                     Brettanomyces
# ...                              ...
# 27657                      Oak Aging
# 27658                      Oak Aging
# 27659                      Vegetable
# 27660                      Oak Aging
# 27661                      Oak Aging
# 27662                      Oak Aging
# 27663                      Oak Aging
# 27664                      Oak Aging
# 27665                      Vegetable
# 27666                      Oak Aging
# 27667                      Oak Aging
# 27668                      Oak Aging
# 27669                      Oak Aging
# 27670                      Oak Aging
# 27671                      Vegetable
# 27672                      Noble Rot
# 27673                      Oak Aging
# 27674                      Oak Aging
# 27675                      Oak Aging
# 27676                      Oak Aging
# 27677                      Oak Aging
# 27678                      Oak Aging
# 27679                      Oak Aging
# 27680                      Oak Aging
# 27681                      Oak Aging
# 27682                      Oak Aging
# 27683                      Oak Aging
# 27684                      Oak Aging
# 27685                      Oak Aging
# 27686                      Oak Aging
#
# [27687 rows x 4 columns]

# %%
top3_profiles.First.value_counts()
# Out:
# Sulfides & Mercaptans            17079
# Volatile Acidity (AceticAcid)    10509
# Oak Aging                           33
# Noble Rot                           22
# Brettanomyces                        6
# Microbial                            5
# Vegetable                            5
# Madeirized (orCooked)                4
# Spice                                4
# General Aging                        3
# Red Fruit                            3
# Tree Fruit                           3
# Cork Taint(TCA)                      3
# Dried Fruit                          2
# Flower                               2
# Tropical Fruit                       2
# Earth                                1
# Black Fruit                          1
# Name: First, dtype: int64

# %% [markdown]
# # other method

# %%
descriptors = wines.description.apply(tokenize_and_stem)
print(descriptors.head())
# Out:
# 0    [immens, in, all, proport, this, wine, defin, ...
# 1    [this, is, an, eleg, and, flavoursom, shiraz, ...
# 2    [a, well, balanc, full, tropic, flavour, with,...
# 3    [a, rubi, tipe, port, blend, from, rubi, caber...
# 4    [dri, wine, with, fruiti, quava, bouquet, and,...
# Name: description, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#define vectorizer parameters
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=20000,
                                   min_df=0.2, stop_words='english',
                                   use_idf=True, 
                                   tokenizer=tokenize_and_stem,
                                   ngram_range=(1,3))

# %time tfidf_matrix = tfidf_vectorizer.fit_transform( \
    wines.description) #fit the vectorizer to wine descr

print(tfidf_matrix.shape)

# %%
terms = tfidf_vectorizer.get_feature_names()

# %%
from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(tfidf_matrix)

# %%
from sklearn.cluster import KMeans

num_clusters = 10

km = KMeans(n_clusters=num_clusters)

# %time km.fit(tfidf_matrix)

clusters = km.labels_.tolist()

# %%
vocab_frame = pd.DataFrame({'words': list(descriptors)}, index = descriptors)
print 'there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame'
print(vocab_frame.head())

# %%
from sklearn.externals import joblib

#uncomment the below to save your model 
#since I've already run my model I am loading from the pickle

# joblib.dump(km, 
#             '/Users/lauren/Google Drive/Data Science/WineData/descr_cluster.pkl')

km = joblib.load('/Users/lauren/Google Drive/Data Science/WineData/descr_cluster.pkl')
clusters = km.labels_.tolist()

# %%
order_centroids = km.cluster_centers_.argsort()[:, ::-1] 

for i in range(num_clusters):
    print "Cluster %d words:" % i 
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        print ' %s' % vocab_frame.ix[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore')

# %%
from nltk.corpus import stopwords
import nltk
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
from nltk.tokenize import word_tokenize
import re

def review_to_wordlist( review, remove_stopwords=True ): 
    """
    from https://www.kaggle.com/c/word2vec-nlp-tutorial
    
    Function to convert a document to a sequence of words,
    optionally removing stop words.  Returns a list of words.
    """

    review_text = review
    #  
    # 2. Remove non-letters
    review_text = re.sub("[^a-zA-Z]"," ", review_text)
    review_text = re.sub('gold', '', review_text)
    review_text = re.sub('silver', '', review_text)
    review_text = re.sub('bronze', '', review_text)
    review_text = re.sub('[0-9]+', '', review_text)
    #
    # 3. Convert words to lower case and split them
    words = review_text.lower().split()
    #
    # 4. Optionally remove stop words (false by default)
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    #
    # 5. Return a list of words
    return(words)


# Define a function to split a review into parsed sentences
def review_to_sentences(review, tokenizer, remove_stopwords=False ):   #from https://www.kaggle.com/c/word2vec-nlp-tutorial
    # Function to split a review into parsed sentences. Returns a 
    # list of sentences, where each sentence is a list of words
    #
    # 1. Use the NLTK tokenizer to split the paragraph into sentences
    if isinstance(review,float):
        return ['']
    else:
        review = review.decode('utf-8')
        raw_sentences = tokenizer.tokenize(review.strip())

    #
    # 2. Loop over each sentence
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append( review_to_wordlist( raw_sentence,remove_stopwords ))
    #
    # Return the list of sentences (each sentence is a list of words,
    # so this returns a list of lists
    return sentences

def sentences_to_list(sentences):
    newList = []
    skipped = 0
    for s in range(len(sentences)):
        try:
            newList += sentences[s]
        except:
            skipped +=1
    print 'Skipping ',skipped,' lines since they are NoneType'
    return newList

def unicodeStrToStr(x):
    try:
        x = map(str, x)
    except:
        pass
    return x

# %% [markdown]
# There are also some words in the tasting notes that are superfluous or unhelpful, so I have defined some functions to remove these

# %%
with open('wine_stopwords.txt') as f:
    wine_stopwords = []
    lines = f.readlines()
    for line in lines:
        wine_stopwords.append(str(line.split('\n')[0]))

def removeWineStopWords(descriptionList):
    global wine_stopwords
    if isinstance(descriptionList,float):
        return descriptionList
    else:
        list_u = []
        [list_u.append(v) for v in descriptionList if v not in wine_stopwords]
        if 'tint' in descriptionList:
            c_index = list_u.index("tint")
            list_u = [list_u[:c_index+1],list_u[c_index+1:]]
        elif 'colour' in descriptionList:
            c_index = list_u.index("colour")
            list_u = [list_u[:c_index+1],list_u[c_index+1:]] 
        elif 'color' in descriptionList:
            c_index = list_u.index("color")
            list_u = [list_u[:c_index+1],list_u[c_index+1:]] 
        return list_u
    
def getFlavoursnotColors(description):
    if isinstance(description,float):
        return []
    elif len(description)==0:
        return description        
    elif isinstance(description[0],unicode):
        return description
    else:
        for i in description:
            if 'tint' in i:
                pass
            elif 'colour' in i:
                pass
            elif 'color' in i:
                pass
            else:
                return i

# %% [markdown]
# Now the normal stopwords are removed...

# %%
descriptions = wines.TastingNotes.str.lower()
descriptionWords = descriptions.apply(lambda x: review_to_sentences(x,tokenizer,True))
descriptionWords = descriptionWords.apply(sentences_to_list)
descriptionWords.head()

# %% [markdown]
# Followed by the wine stopwords. I also make sure that I am not using visible descriptions in my analysis

# %%
cleanDescriptions = descriptionWords.apply(removeWineStopWords)

cleanDescriptionFlavours = cleanDescriptions.apply(getFlavoursnotColors)
cleanDescriptionFlavours.head()

# %% [markdown]
# I then read in the flavour profiles

# %%
flavourProfiles = pd.read_csv('flavourProfiles.csv',skiprows=1,names=['Profile','Varieties'])
flavourProfiles.Varieties = flavourProfiles.Varieties.str.lower()#.str.split(',')
# profileText = flavourProfiles.Varieties.str.replace(',',' ').str.cat(sep='')
flavourProfiles

# %%
from difflib import SequenceMatcher

def similarList(lst, b):
    similarities = []
    for i in range(len(lst)):
        similarities.append(SequenceMatcher(None, lst, b).ratio())
    return similarities

def assignFlavourProfile(flavourList,flavourProfiles,winestopwords):
    """
    This function looks at the leftover words in the tasting notes and either:
    1) Finds extra stopwords that were missed
    2) Updates the flavour profile to recognise new (possibly misspelled) descriptors
    3) Adds the word to a dictionary so tasting notes can be mapped to Flavour Profiles
    """
    profileDict= {}
    #address easy fits and multi-word flavours first
    for n in nltk.bigrams(flavourList):
        combinedBigram = n[0]+' '+n[1]
        if flavourProfiles['Varieties'].str.contains(combinedBigram).any():
            location =  flavourProfiles['Profile'].where(flavourProfiles['Varieties'].str.contains(combinedBigram))
            profileDict[combinedBigram] = list(location.dropna())[0]    
            
    #now we consider the flavours with frivolous adjectives
    for n in range(len(flavourList)):
        if n>0 and n%50 ==0:
            contin = raw_input('Stop or continue?[[s]/c]')
        else: 
            contin = 'c'
        if contin == 'c':                             
            if flavourList[n] in profileDict:
                pass
            else:
                f = flavourList[n]
                profile = []
                if flavourProfiles['Varieties'].str.contains(f).any():

                    check = flavourProfiles['Varieties'].where(flavourProfiles['Varieties'].str.contains(f)).dropna()
                    checkList = list(check)[0]
                    location =  flavourProfiles['Profile'].where(flavourProfiles['Varieties'].str.contains(f))
                    profile.append(list(location.dropna())[0]) 
                else:
                    print f, 'does not seem to belong to any profile.'
                    print 'Profiles are\n',flavourProfiles.Profile
                    user_input = raw_input('What profile should %s belong to? Return "w" if this is an winestopword, "p" if you want to see the previous word or "n" if you want to see the next word, else return the profile number'%f)
                    if user_input == 'w': 
                        winestopwords.append(f)
                    elif user_input == 'p': 
                        try:
                            f = flavourList[n-1]+' '+flavourList[n]
                        except:
                            pass
                        user_input = raw_input('What profile should %s belong to in context %s? Return x if still cannot be classified, else the profile number'%(f,flavourList))
                    elif user_input == 'n': 
                        try:
                            f = flavourList[n]+' '+flavourList[n+1]
                        except:
                            pass
                        user_input = raw_input('What profile should %s belong to? Return x if still cannot be classified, else the profile number'%f)
                    if user_input not in ['w','x']:
                        user_input = int(user_input)
                        flavourProfiles.Varieties[user_input]+=','+str(f)
                        profile.append(flavourProfiles.Profile[user_input])
                if len(profile)>1:
                    print 'Flavour is ',flavourList[n],'and chosen profiles are',profile
                    profileChoice = raw_input('What profile should  be chosen? Please choose index or "n" to go back to original list')
                    if profileChoice == 'n':
                        print 'Profiles are\n',flavourProfiles.Profile
                        profileChoice = raw_input('What profile should %s belong to? Return the profile number'%flavourList[n])
                        profile = list(flavourProfiles.Profile[int(profileChoice)])
                    else: 
                        profile = profile[int(profileChoice)]
                    profile = list(profileChoice)
                if len(profile) > 0:
                    profileDict[flavourList[n]] = profile[0]
        else:
            return profileDict,winestopwords,flavourList
    return profileDict,winestopwords

# %% [markdown]
# Now I combine all words in the descriptions and take the set of descriptors to check for stoppwords and create the dictionary to map tasting notes to profiles

# %%
uniqueFlavours = sentences_to_list(list(cleanDescriptionFlavours))
print 'Description words ',len(uniqueFlavours)
uniqueFlavours = list(set(uniqueFlavours))
print 'Unique description words: ',len(uniqueFlavours)

# %%
assignDict,wineStopWords = assignFlavourProfile(uniqueFlavours,flavourProfiles,wine_stopwords)
print assignDict

with open('wine_stopwords.txt','w') as f:
    for a in wineStopWords:
        if a == wineStopWords[-1]:
            f.write(a)
        else:
            f.write(a+'\n')
flavourProfiles.to_csv('flavourProfiles.csv',columns =['Profile','Varieties'])

# %%
wines['clean_TastingNotes'] = cleanDescriptionFlavours 
wines.clean_TastingNotes.head()

# %% [markdown]
# ### Map tasting notes to profile

# %%
def flavour_to_profile(assignDict,row):
    """
    Take the flavours identified from the tasting notes and map them to profiles
    The result will be a table where the row will show '1' if the profile is present in that wine and '0' otherwise
    """
    profiles = []
    for f in row.clean_TastingNotes:
        try:
            if row[assignDict[f]] ==1:
                pass
            else:
                row[assignDict[f]] +=1
        except:
            pass
    return row
    
wine_FlavourProfiles = wines[['WineName','WineType','Vintage_dateTime','clean_TastingNotes']].dropna()
wine_FlavourProfiles.clean_TastingNotes = wine_FlavourProfiles.clean_TastingNotes.apply(lambda y: np.nan if len(y)==0 else y)
for p in flavourProfiles.Profile:
    wine_FlavourProfiles[p] = 0
wine_FlavourProfiles = wine_FlavourProfiles.dropna()
wine_FlavourProfiles = wine_FlavourProfiles.apply(lambda row: flavour_to_profile(assignDict,row), axis = 1)
wine_FlavourProfiles.describe()

# %%
wines.info()
wines.to_csv('../WineData/WineData_withFlavours.csv', columns = wines.columns, encoding='utf-8')

# %%
print 'Number of instances of each profile: '
print wine_FlavourProfiles.sum(axis = 0)
wine_sums = wine_FlavourProfiles.sum(axis = 1)
print 'Number of wines where a profile has been identified: ',sum(wine_sums > 0)
wine_FlavourProfiles.to_csv('../WineData/wine_FlavourPofiles.csv', columns = wine_FlavourProfiles.columns, encoding='utf-8')
